# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
tf.VERSION
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# '1.15.0'

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd '/content/drive/My Drive/Work/2018 X/X NLP Research Paper/VDCNN_2'
# Out:
# /content/drive/My Drive/Work/2018 X/X NLP Research Paper/VDCNN_2

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11238478418676874826
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 18225144912936065026
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 3996025707228682720
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11330115994
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7556981389543399763
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Using TensorFlow backend.
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
# %run -i train.py
# Out:
# Parameters:
# --------------------
# alsologtostderr=False
# batch_size=64
# database_path=final_dataset/
# depth=17
# evaluate_every=100
# log_dir=
# logtostderr=False
# num_epochs=10
# only_check_args=False
# op_conversion_fallback_to_while_loop=False
# pdb_post_mortem=False
# pool_type=max
# profile_file=None
# run_with_pdb=False
# run_with_profiling=False
# sequence_length=1024
# shortcut=False
# showprefixforinfo=True
# sorted=False
# stderrthreshold=fatal
# test_random_seed=301
# test_randomize_ordering_seed=None
# test_srcdir=
# test_tmpdir=/tmp/absl_testing
# use_bias=False
# use_cprofile_for_profiling=True
# v=-1
# verbosity=-1
# xml_output_file=
#
# Loading data...
# Files loaded
# Files loaded
# Loading data succees...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# 2019-11-03T16:49:28.080943: Model saved as json.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 100000 samples, validate on 15361 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1120: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1112: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1122: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1125: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/10
#     64/100000 [..............................] - ETA: 1:51:29 - loss: 1.1218 - acc: 0.5781WARNING:tensorflow:From /content/drive/My Drive/Work/2018 X/X NLP Research Paper/VDCNN_2/custom_callbacks.py:24: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
#   6400/100000 [>.............................] - ETA: 10:06 - loss: 0.8743 - acc: 0.6573
# 2019-11-03T16:50:57.986108: Saving model with val_acc 0.601393, at step 100, epoch 1.
#
#  19200/100000 [====>.........................] - ETA: 13:27 - loss: 0.8784 - acc: 0.6584
# 2019-11-03T16:53:21.894458: Saving model with val_acc 0.622551, at step 300, epoch 1.
#
#  25600/100000 [======>.......................] - ETA: 12:47 - loss: 0.8815 - acc: 0.6580
# 2019-11-03T16:54:34.055994: Saving model with val_acc 0.638175, at step 400, epoch 1.
#
# 100000/100000 [==============================] - 1144s 11ms/step - loss: 0.8908 - acc: 0.6585 - val_loss: 0.9614 - val_acc: 0.6323
#
# Epoch 00001: val_acc did not improve from 0.63817
# Epoch 2/10
#  72768/100000 [====================>.........] - ETA: 5:00 - loss: 0.8759 - acc: 0.6645
# 2019-11-03T17:36:49.188015: Saving model with val_acc 0.643252, at step 2700, epoch 2.
#
# 100000/100000 [==============================] - 1167s 12ms/step - loss: 0.8735 - acc: 0.6659 - val_loss: 1.0305 - val_acc: 0.5807
#
# Epoch 00002: val_acc did not improve from 0.64325
# Epoch 3/10
#  49536/100000 [=============>................] - ETA: 8:59 - loss: 0.8569 - acc: 0.6726
# 2019-11-03T17:51:43.370289: Saving model with val_acc 0.646117, at step 3900, epoch 3.
#
# 100000/100000 [==============================] - 1132s 11ms/step - loss: 0.8590 - acc: 0.6707 - val_loss: 1.1294 - val_acc: 0.6017
#
# Epoch 00003: val_acc did not improve from 0.64612
# Epoch 4/10
#  77504/100000 [======================>.......] - ETA: 4:10 - loss: 0.8403 - acc: 0.6790
# 2019-11-03T18:16:10.257662: Saving model with val_acc 0.66148, at step 5900, epoch 4.
#
# 100000/100000 [==============================] - 1167s 12ms/step - loss: 0.8439 - acc: 0.6778 - val_loss: 1.3892 - val_acc: 0.5567
#
# Epoch 00004: val_acc did not improve from 0.66148
# Epoch 5/10
#  73472/100000 [=====================>........] - ETA: 4:50 - loss: 0.8230 - acc: 0.6855
# 2019-11-03T18:34:38.288552: Saving model with val_acc 0.667209, at step 7400, epoch 5.
#
# 100000/100000 [==============================] - 1164s 12ms/step - loss: 0.8282 - acc: 0.6838 - val_loss: 0.9119 - val_acc: 0.6544
#
# Epoch 00005: val_acc did not improve from 0.66721
# Epoch 6/10
#  88640/100000 [=========================>....] - ETA: 2:02 - loss: 0.8136 - acc: 0.6888
# 2019-11-03T18:56:36.268439: Saving model with val_acc 0.672808, at step 9200, epoch 6.
#
# 100000/100000 [==============================] - 1128s 11ms/step - loss: 0.8155 - acc: 0.6880 - val_loss: 1.2250 - val_acc: 0.5543
#
# Epoch 00006: val_acc did not improve from 0.67281
# Epoch 7/10
# 100000/100000 [==============================] - 1161s 12ms/step - loss: 0.7998 - acc: 0.6961 - val_loss: 1.0232 - val_acc: 0.6252
#
# Epoch 00007: val_acc did not improve from 0.67281
# Epoch 8/10
# 100000/100000 [==============================] - 1160s 12ms/step - loss: 0.7863 - acc: 0.7002 - val_loss: 0.9654 - val_acc: 0.6373
#
# Epoch 00008: val_acc did not improve from 0.67281
# Epoch 9/10
# 100000/100000 [==============================] - 1126s 11ms/step - loss: 0.7740 - acc: 0.7044 - val_loss: 0.9886 - val_acc: 0.6392
#
# Epoch 00009: val_acc did not improve from 0.67281
# Epoch 10/10
# 100000/100000 [==============================] - 1160s 12ms/step - loss: 0.7616 - acc: 0.7093 - val_loss: 1.0091 - val_acc: 0.6303
#
# Epoch 00010: val_acc did not improve from 0.67281
# ------------------------------
# 2019-11-03T20:15:37.013229: Done training.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# ------------------------------

# %%
tf.get_default_graph()

# %%
# !ls
# Out:
# checkpoints	     final_dataset    logs_nul	   testing_repo.ipynb  vdcnn.py
# custom_callbacks.py  k_maxpooling.py  logs_test    todos.md
# data_helper.py	     logs	      __pycache__  train.py
# _DS_Store	     logs_epoch5      README.md    vdcnn_model.json
